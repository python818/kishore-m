# %%
import numpy as np
b = np.array([[10,20,30],[40,50,60]])
print("two dimensional array:",b)
# Out:
# two dimensional array: [[10 20 30]
#  [40 50 60]]

# %%
import numpy as np
b = np.array([[10,20,30],[40,50,60],[70,80,90]])
print("\nthree dimensional array:\n",b)
# Out:
# three dimensional array:
#  [[10 20 30]
#  [40 50 60]
#  [70 80 90]]

# %%
import numpy as np
b = np.zeros((3,3))
print("\n Array with all zeros:\n",b)
# Out:
#  Array with all zeros:
#  [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
import numpy as np
b = np. random.random((2,2))
print("\n random value:\n",b)
# Out:
#  random value:
#  [[0.87188017 0.06843263]
#  [0.25405638 0.27863133]]

# %%
import numpy as np
b = np.arange(0,20,4)
print("\nsequence array:\n",b)
# Out:
# sequence array:
#  [ 0  4  8 12 16]

# %%
 import numpy as np
b = np.array([[10,20],[40,50],[70,80]])
newarr=b.reshape(2,3)
print("\nthree dimensional array:\n",b)
print("\n reshaped array[2,3]:\n",newarr)
# Out:
# three dimensional array:
#  [[10 20]
#  [40 50]
#  [70 80]]
#
#  reshaped array[2,3]:
#  [[10 20 40]
#  [50 70 80]]

# %%
import numpy as np
b = np.array([10,20,30])
print("one dimensional array:",b)
# Out:
# one dimensional array: [10 20 30]

# %%
import numpy as np
original = np.array([[10,20],[40,50],[70,80]])
flat=original.flatten()
print("\n Original array:\n",b)
print("\n flatten array:\n",flat)
# Out:
#  Original array:
#  [[10 20]
#  [40 50]
#  [70 80]]
#
#  flatten array:
#  [10 20 40 50 70 80]

# %%
import numpy as np
b = np.array([[10,20,30],[40,50,60],[70,80,90]])
print("\nnumber of dimensional:\n",b.ndim)
# Out:
# number of dimensional:
#  2
