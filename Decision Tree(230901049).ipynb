# %%
import matplotlib.pyplot as plt
import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
import matplotlib.pyplot as plt
df=pandas.read_csv("datatree Sheet1.csv")
print(df)
# Out:
#     S.No  Age  Rank Nationality   go  experience
# 0      1   36     4          uk  yes          10
# 1      2   34     5         usa   no           2
# 2      3   34     6         usa  yes          12
# 3      4   78     7          uk   no          12
# 4      5   56     8         na   yes           4
# 5      6   56     9          na  yes           5
# 6      7   56     9       india  yes          11
# 7      8   45     8         usa   no          10
# 8      9   87     7          uk   no           5
# 9     10   32     4        asia   no           6
# 10    11   43     2        asia  yes           7
# 11    12   98     2       japan  yes           8

# %%
d={'uk':0,'usa':1,'na':2}
df['Nationality']=df['Nationality'].map(d)
d={'yes':1,'no':0}
df['GO']=df['go'].map(d)
features=['Age','experience','Rank','Nationality']
x=df[features]
y=df['go']
dtree=DecisionTreeClassifier()
dtree=dtree.fit(x,y)
tree.plot_tree(dtree,feature_names=features)
plt.show()
