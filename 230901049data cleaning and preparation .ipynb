# %%
import pandas as pd
pd.set_option('display.max_columns',10)
print("original date:\n")
df=pd.read_excel("sheet.xlsx")
print(df)
# Out:
# original date:
#
#     s.no  roll    name english Tamil Maths science social  total Unnamed: 9
# 0      1     1   ashok      98    90    77      78     78    421        NaN
# 1      2     2     sam      99    99    99      99     99    495        NaN
# 2      3     3     sai      55    56    86      78     78    353        NaN
# 3      4     4   peter      66    65    67      78     87    363        NaN
# 4      5     5   roman            99     9              0    108        NaN
# 5      6     6    root      45    88    77      44     88    342        NaN
# 6      7     7   virat       5    77    66      33           181        NaN
# 7      8     8   dhoni       6                  22     66     94        NaN
# 8      9     9   rohit       7    44    33      11      7    102        NaN
# 9     10    10   rahul      85     3     2      66     77    233        NaN
# 10    11    11    gill       6    67    22             88    183        NaN
# ...

# %%
f=df['name'].str.strip()
f.to_excel("empty.xlsx")
print(f)
# Out:
# 0      ashok
# 1        sam
# 2        sai
# 3      peter
# 4      roman
# 5       root
# 6      virat
# 7      dhoni
# 8      rohit
# 9      rahul
# 10      gill
# 11      rutu
# 12     ishan
# 13    sachin
# 14    ashwin
# 15     smith
# 16     shami
# 17        ji
# 18      head
# 19      jadu
# Name: name, dtype: object

# %%
import pandas as pd
print("\nReplaceValue:")
k=df.fillna(method='Pad')
print(k)
print("\n updated list\n")
k.to_excel("empty.xlsx")
print(k)
# Out:
# ReplaceValue:
#     Unnamed: 0.1  Unnamed: 0  s.no  roll    name english Tamil Maths science  \
# 0              0           0     1     1   ashok      98    90    77      78
# 1              1           1     2     2     sam      99    99    99      99
# 2              2           2     3     3     sai      55    56    86      78
# 3              3           3     4     4   peter      66    65    67      78
# 4              4           4     5     5   roman            99     9
# 5              5           5     6     6    root      45    88    77      44
# 6              6           6     7     7   virat       5    77    66      33
# 7              7           7     8     8   dhoni       6                  22
# 8              8           8     9     9   rohit       7    44    33      11
# 9              9           9    10    10   rahul      85     3     2      66
# 10            10          10    11    11    gill       6    67    22
# ...

# %%
import pandas as pd
print("\n drop one particular column and its values:\n")
k.drop(['science'],axis=1,inplace=True)
print(k)
k.to_excel("sheet.xlsx")
print(k)
# Out:
#  drop one particular column and its values:
#
#     Unnamed: 0.1  Unnamed: 0  s.no  roll    name english Tamil Maths  total  \
# 0              0           0     1     1   ashok      98    90    77    421
# 1              1           1     2     2     sam      99    99    99    495
# 2              2           2     3     3     sai      55    56    86    353
# 3              3           3     4     4   peter      66    65    67    363
# 4              4           4     5     5   roman            99     9    108
# 5              5           5     6     6    root      45    88    77    342
# 6              6           6     7     7   virat       5    77    66    181
# 7              7           7     8     8   dhoni       6                 94
# 8              8           8     9     9   rohit       7    44    33    102
# 9              9           9    10    10   rahul      85     3     2    233
# 10            10          10    11    11    gill       6    67    22    183
# ...

# %%
import pandas as pd
n=pd.read_excel("sheet.xlsx")
print(n)
y=n.replace({89:88})
print(y)
y.to_excel("empty.xlsx")
# Out:
#     Unnamed: 0  s.no  roll    name english Tamil Maths science  total  \
# 0            0     1     1   ashok      98    90    77      78    421
# 1            1     2     2     sam      99    99    99      99    495
# 2            2     3     3     sai      55    56    86      78    353
# 3            3     4     4   peter      66    65    67      78    363
# 4            4     5     5   roman            99     9            108
# 5            5     6     6    root      45    88    77      44    342
# 6            6     7     7   virat       5    77    66      33    181
# 7            7     8     8   dhoni       6                  22     94
# 8            8     9     9   rohit       7    44    33      11    102
# 9            9    10    10   rahul      85     3     2      66    233
# 10          10    11    11    gill       6    67    22            183
# 11          11    12    12    rutu      34          11       6    139
# ...

# %%
df=pd.read_excel("empty.xlsx")
print(df)
new=df['english'].isin([89])
print(df[new])
# Out:
#     Unnamed: 0.1  Unnamed: 0  s.no  roll    name english Tamil Maths science  \
# 0              0           0     1     1   ashok      98    90    77      78
# 1              1           1     2     2     sam      99    99    99      99
# 2              2           2     3     3     sai      55    56    86      78
# 3              3           3     4     4   peter      66    65    67      78
# 4              4           4     5     5   roman            99     9
# 5              5           5     6     6    root      45    88    77      44
# 6              6           6     7     7   virat       5    77    66      33
# 7              7           7     8     8   dhoni       6                  22
# 8              8           8     9     9   rohit       7    44    33      11
# 9              9           9    10    10   rahul      85     3     2      66
# 10            10          10    11    11    gill       6    67    22
# ...
